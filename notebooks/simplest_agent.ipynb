# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    YOu are a helpful assistant giving out nutrition advice.
    You give concise answers.
    """
)

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Bananas are quite healthy as part of a balanced diet.
#
#     Key nutrients per medium banana (about 118 g):
#     - Potassium: supports blood pressure and heart health
#     - Vitamin B6: important for metabolism and brain health
#     - Vitamin C and fiber: antioxidant and digestive benefits
#
#     About 105–110 calories and ~14 g sugar; they’re convenient, portable, and good for quick energy, especially around workouts.
#
#     Tips:
#     - Pair with protein or healthy fats for more balanced satiety.
#     - If you’re watching sugar intake or have kidney issues, moderate portions.
#
#     Overall, a moderate, everyday fruit option.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Bananas are a healthy, convenient fruit.
#
# Key benefits:
# - Good source of potassium, vitamin C, vitamin B6, and dietary fiber.
# - Low in fat and calories for a fruit.
# - Provide quick energy from natural sugars.
#
# Things to consider:
# - Higher sugar content as bananas ripen; portion size matters for diabetes or blood sugar control.
# - Eat as part of a balanced diet with a variety of fruits and vegetables.
#
# Typical: ~100 kcal, ~3 g fiber, ~400–450 mg potassium per medium banana.

# %% [markdown]
# _Good Job!_
