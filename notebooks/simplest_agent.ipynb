# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    YOu are a helpful assistant giving out nutrition advice.
    You give concise answers.
    """
)

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are Mangoes?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Mangoes are healthy in moderation. They’re rich in:
#     - Vitamins A and C, fiber, and several antioxidants.
#     - About 100–135 calories per cup (cubed), with natural sugars.
#
#     Health tips:
#     - Good for immunity, skin, and eye health; supports digestion due to fiber.
#     - Keep portions ~1 cup per day to manage sugar intake.
#     - Diabetics should monitor carb/sugar effects; pair with protein/fiber to slow absorption.
#
#     Possible downsides:
#     - High in sugar and calories if eaten in large amounts.
#     - Allergies and mouth irritation are rare but possible.
#
#     Storage: store at room temp until ripe, then refrigerate 5–7 days. Enjoy ripe mango plain, in smoothies, salads, or salsas.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are mangoes?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Mangoes are generally very healthy when eaten in moderation.
#
# Key benefits:
# - Rich in vitamin C, vitamin A (beta-carotene), and fiber.
# - Contain antioxidants (e.g., mangiferin) and potassium.
# - May support immunity, skin, and digestion.
#
# Things to watch:
# - They’re relatively high in natural sugars; portion size matters for blood sugar control.
# - About 100 kcal per cup of cubed mango; more if larger.
#
# Tips:
# - Pair with protein or fat to balance blood sugar.
# - One cup (about 165 g) is a common healthy portion; adjust for your calories and goals.
#
# Bottom line: Mangoes are nutritious and can be part of a healthy diet when eaten in reasonable portions.

# %% [markdown]
# _Good Job!_
