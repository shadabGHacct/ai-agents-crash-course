# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    YOu are a helpful assistant giving out nutrition advice.
    You give concise answers.
    """
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 nutrition_agent = Agent(
#       2     name="Nutrition Assistant",
#       3     instructions="""
#       4     YOu are a helpful assistant giving out nutrition advice.
#       5     You give concise answers.
#       6     """
#       7 )
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1481, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1523, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1324, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1961, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# File ~/.local/lib/python3.13/site-packages/debugpy/_vendored/pydevd/pydevd.py:2188, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2185             from_this_thread.append(frame_custom_thread_id)
#    2187     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2188         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2190 frames_list = None
#    2192 if keep_suspended:
#    2193     # This means that we should pause again after a set next statement.
#
# File ~/.local/lib/python3.13/site-packages/debugpy/_vendored/pydevd/pydevd.py:2257, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2254                 queue.put(internal_cmd)
#    2255                 wait_timeout = TIMEOUT_FAST
# -> 2257         notify_event.wait(wait_timeout)
#    2258         notify_event.clear()
#    2260 finally:
#
# File /usr/local/lib/python3.13/threading.py:659, in Event.wait(self, timeout)
#     657 signaled = self._flag
#     658 if not signaled:
# --> 659     signaled = self._cond.wait(timeout)
#     660 return signaled
#
# File /usr/local/lib/python3.13/threading.py:363, in Condition.wait(self, timeout)
#     361 else:
#     362     if timeout > 0:
# --> 363         gotit = waiter.acquire(True, timeout)
#     364     else:
#     365         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are Mangoes?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Mangoes are nutritious and can be part of a healthy diet. Key points:
#
#     - Nutrients: rich in vitamin C, vitamin A (from beta-carotene), fiber, potassium, and antioxidants (including mangiferin).
#     - Health benefits: supports immunity, eye health, digestion, and may help with heart health due to fiber and potassium.
#     - Calories: about 60–70 kcal per 100 g; a cup of diced mango (~165 g) is ~100–110 kcal with ~24 g carbs.
#     - Considerations: relatively high sugar content, so portions matter for diabetes or glucose control. Ripe fruit is easiest to digest for most people.
#     - Tips: eat whole fruit to get fiber; avoid the rind (urushiol-like compounds) and wash well. If allergic or sensitive to latex, watch for reactions.
#
#     Short answer: healthy and nutrient-dense in moderation; watch portion if you’re tracking sugars.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are mangoes?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Mangoes are fairly healthy when eaten in moderation.
#
# Nutrients per roughly 1 cup (165 g) sliced:
# - Calories: ~99
# - Fiber: ~3 g
# - Vitamin C: ~60% DV
# - Vitamin A (in the form of beta-carotene): ~20–30% DV
# - Potassium and several antioxidants
#
# Benefits:
# - Very good vitamin C and A support immune and eye health
# - Fiber aids digestion
# - Antioxidants may help protect cells
#
# Things to watch:
# - Natural sugars are relatively high; portion control matters if you’re watching sugar or calories
# - Some people have allergies or a latex-fruit syndrome
# - Pesticide exposure can be reduced by washing or choosing organic, if possible
#
# Bottom line: a mango a day can be part of a healthy diet, especially when balanced with protein and fats.

# %% [markdown]
# _Good Job!_
